# %% [markdown]
# #### Import Libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# #### Basic Information about

# %%
train_data = pd.read_parquet('data/train_data.parquet')
test_data = pd.read_parquet('data/test_data.parquet')
print('train dataset shape: ', train_data.shape)
print('test dataset shape: ', test_data.shape)
# Out:
# train dataset shape:  (8760, 7)
# test dataset shape:  (720, 4)

# %% [markdown]
# #### Info and Statistics

# %%
print('Info:')
print(train_data.info())
print('Statistics:')
print(train_data.describe())
# Out:
# Info:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 8760 entries, 2023-01-01 00:00:00 to 2023-12-31 23:00:00
# Data columns (total 7 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   system_load_forecast   8760 non-null   float64
#  1   system_solar_forecast  8760 non-null   float64
#  2   system_wind_forecast   8760 non-null   float64
#  3   outage_forecast        8760 non-null   float64
#  4   rtlmp                  8760 non-null   float64
#  5   dalmp                  8760 non-null   float64
#  6   wind_power_mw          8760 non-null   float64
# dtypes: float64(7)
# memory usage: 547.5 KB
# None
# Statistics:
#        system_load_forecast  system_solar_forecast  system_wind_forecast  \
# count           8760.000000            8760.000000           8760.000000
# mean           29569.186126            2198.216885          18744.466569
# std            15924.720277            3519.393114           7917.021042
# min             9904.269734               0.000000           3498.569860
# 25%            18110.054441               0.000000          13404.328659
# 50%            21795.513984               0.000000          17415.970119
# 75%            40537.125030            3343.293939          24777.703707
# max            98791.148020           15426.418980          39457.504766
#
#        outage_forecast        rtlmp        dalmp  wind_power_mw
# count      8760.000000  8760.000000  8760.000000    8760.000000
# mean          0.013435   117.102780    58.409637      49.607433
# std           0.013091   126.291611    65.461470      33.959027
# min          -0.008753   -54.600000   -30.460000       0.000000
# 25%           0.006931    16.917500    18.127500      19.585665
# 50%           0.010442    86.085000    40.145000      48.710281
# 75%           0.014567   186.425000    68.350000      73.605654
# max           0.120577  2906.350000   492.490000     148.230348

# %% [markdown]
# #### Time series plot

# %%
for var in train_data.columns:
    plt.figure(figsize=(10, 5))
    plt.plot(train_data[var])
    plt.title(f'{var} in train dataset')
    plt.show()

# %% [markdown]
# #### Create Correlation Heatmap

# %%
plt.figure(figsize=(12, 8))
correlation_matrix = train_data.corr()
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', center=0)
plt.title('Correlation Matrix')
plt.tight_layout()
plt.show()
